# %% [markdown]
# <H1><b>Panda</b></H1>

# %% [markdown]
# <b>Panel-data</b>: Data set that include multiple observation over multiple periods of time

# %% [markdown]
# <h3>we want to use the Panta first we have to setup or install the <b>NumPy</b></h3><br>But this both are alorady come wiht the Anocanda<br> <h2>pip install panda --upgrade</h2>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# <h2>Now code</h2>

# %%
import pandas as pd

# %%
data_set = ['A', 'B', 'C', 'D']
data_set
# Out:
# ['A', 'B', 'C', 'D']

# %%
type(data_set)
# Out:
# list

# %%
product_categories = pd.Series(data_set)
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
type(product_categories)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
array_a = np.array([1,2,3,4])
array_a
# Out:
# array([1, 2, 3, 4])

# %%
Series_a = pd.Series(array_a)

# %%
Series_a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# <h1>Introduction to pandas Series - Exercise #1</h1>

# %% [markdown]
# <pre>
# Create a list called 'employee_names', which
# should contain the following names:
# <ul>
#     <li>Amy White</li>
#     <li>Jack Stewart</li>
#     <li>Richard Lauderdale</li>
#     <li>Sara Johnson</li>
# </ul>
# Please don't forget to use the <p style="color:orange;">print()</p> function to print out the desired output.
# </pre>

# %%
import pandas as pd 
employee_names = ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']
print(employee_names)
# Out:
# ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']

# %% [markdown]
# <h1>Indexing</h1>

# %%
import pandas as pd
pricess_per_category = {'YASH':22, 'AMAN':21, 'LAVINI':22, 'JOSHUA':23, 'RAJ':26}
pricess_per_category
# Out:
# {'YASH': 22, 'AMAN': 21, 'LAVINI': 22, 'JOSHUA': 23, 'RAJ': 26}

# %%
type(pricess_per_category)
# Out:
# dict

# %%
ans_1 = pd.Series(pricess_per_category)

# %%
ans_1
# Out:
# YASH      22
# AMAN      21
# LAVINI    22
# JOSHUA    23
# RAJ       26
# dtype: int64

# %%
ans_1.index
# Out:
# Index(['YASH', 'AMAN', 'LAVINI', 'JOSHUA', 'RAJ'], dtype='object')
