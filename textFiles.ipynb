# %%
fileName = 'readData.txt'

# %%
fileName
# Out:
# 'readData.txt'

# %%
openFile = open(fileName, mode= 'r')

# %%
openFile
# Out:
# <_io.TextIOWrapper name='readData.txt' mode='r' encoding='cp1252'>

# %%
# here i wse directly it will erese the data 
openFile.read()
# Out:
# ''

# %%
# the best practice to write the code for read it like this 
file_1 = open(fileName, mode='r')
display = file_1.read()
display
# Out:
# 'Hello this is the test data file there is some rendom data i enter.'

# %%
# to checking the file is closed or not 
file_1.closed
# Out:
# False

# %%
# now we have the closed the file 
file_1.close()

# %%
# now againg chaking that the file is closed or not 
file_1.closed
# Out:
# True

# %%
openFile.closed
# Out:
# False

# %%
openFile.close()

# %%
openFile.closed
# Out:
# True

# %%
print(display)
# Out:
# Hello this is the test data file there is some rendom data i enter.

# %% [markdown]
# <h1>There is the anothere pro way to write the read the data </h1

# %%
with open(fileName, 'r') as file:
    text = file.read()
print(text)
# Out:
# Hello this is the test data file there is some rendom data i enter.

# %% [markdown]
# <h2>Now we have to write in the the </h2>
# <h3><b>this method totaly change the data of the file, it will erase the data, and re-write the new data</b></h3>

# %%
with open(fileName, 'w') as filewrite:
    filewrite.write('hello its Yash Malviya')

# %%
with open(fileName, 'r') as file:
    text = file.read()
print(text)
# Out:
# hello its Yash Malviya
