# %% [markdown]
# <h1>NumPy Basics</h1>

# %% [markdown]
# <h3><b>Instaling & Updating the Package</b></h3>

# %% [markdown]
# <p>
#     NumPy is pre-Install while i use "<b>Anaconda</b>"</br>
#     To get the latest verson <b>pip install numpy --upgrade</b>
# </p>

# %%
import numpy as np

# %% [markdown]
# <h3><b>Using Numpy</b></h3>

# %%
array_v = np.array([1,2,3])

# %%
array_v
# Out:
# array([1, 2, 3])

# %% [markdown]
# <h4>Now go for 2D Array it's mean "Matriex"</h4>

# %%
array_m = np.array([[1,2,3],[4,5,6]])
array_m
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# <h2>NumPy Basics - Exercise #1</h2>

# %% [markdown]
# <ol>
#     <li>Import the NumPy library using the conventional alias.</li>
#     <li>Create a one-dimensional NumPy array containing the following values in order:
#         <br> <b>4, 5, 7, 10</b></li>
#     <li>Print the contents of the array.</li>
#     <li>Print the type of the variable to verify that it is a<b> numpy.ndarray</b>.</li>
# </ol>

# %%
import numpy as np

# %%
array_1 = np.array([4,5,7,10])

# %%
print(array_1)
print(type(array_1))
# Out:
# [ 4  5  7 10]
# <class 'numpy.ndarray'>

# %% [markdown]
# <h2>NumPy Basics - Exercise #2</h2>

# %% [markdown]
# <pre>
# The NumPy library has been imported using the conventional alias,
# and a one-dimensional NumPy array has been created containing the
# following values in order:
# <b>4, 5, 7, 10</b>
# </pre>

# %% [markdown]
# <ol>
#     <li>Create a two-dimensional array using two lists - one with the values 4 and 5, and the other - with 7 and 10. For simplicity, call this array array_2.</li>
#     <li>Print the contents of array_2.</li>
#     <li> Compute and display the mean of array_1 and the overall mean of array_2</li>
#     <li> Compute and display the row-wise mean of array_2.</li>
#     <li> Compute and display the column-wise mean of array_2.</li>
# </ol>

# %%
import numpy as np

# %%
array_2 = np.array([[4,5],[7,10]])

# %%
print(array_2)
# Out:
# [[ 4  5]
#  [ 7 10]]

# %%
print(np.mean(array_1))
print(np.mean(array_2))
# Out:
# 6.5
# 6.5

# %%
print(np.mean(array_2, axis = 1))
# Out:
# [4.5 8.5]

# %%
print(np.mean(array_2, axis = 0))
# Out:
# [5.5 7.5]
