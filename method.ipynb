# %%
import pandas as pd

# %%
start_data_deposits = pd.Series({
    '7/4/2014'  : 2000,
    '1/4/2015'  : 2200,
    '12/8/2012' : 1000,
    '2/20/2015' : 2400,
    '10/28/2013': 2600,
    '3/15/2014' : 1800,
    '6/9/2013'  : 2100,
    '8/22/2014' : 2300,
    '11/5/2013' : 2500,
    '5/17/2014' : 2700,
    '9/30/2012' : 2900,
    '12/12/2014': 3100,
    '2/8/2015'  : 3300,
    '4/1/2013'  : 3500,
    '7/19/2014' : 3700,
    '10/10/2012': 3900,
    '4/19/2015' : 5000
}
)

# %%
start_data_deposits
# Out:
# 7/4/2014      2000
# 1/4/2015      2200
# 12/8/2012     1000
# 2/20/2015     2400
# 10/28/2013    2600
# 3/15/2014     1800
# 6/9/2013      2100
# 8/22/2014     2300
# 11/5/2013     2500
# 5/17/2014     2700
# 9/30/2012     2900
# 12/12/2014    3100
# 2/8/2015      3300
# 4/1/2013      3500
# 7/19/2014     3700
# 10/10/2012    3900
# 4/19/2015     5000
# dtype: int64

# %%
start_data_deposits.sum()
# Out:
# np.int64(47000)

# %%
start_data_deposits.max()
# Out:
# 5000

# %%
start_data_deposits.min()
# Out:
# 1000

# %%
start_data_deposits.idxmax()
# Out:
# '4/19/2015'

# %% [markdown]
# <h3>this help to print top 5 Data ".head()"</h3>.
# <h3>this help to print last 5 Data ".tail()"</h3>.

# %%
start_data_deposits.head()
# Out:
# 7/4/2014    2000
# 1/4/2015    2200
# dtype: int64

# %%
start_data_deposits.tail()
# Out:
# 2/8/2015      3300
# 4/1/2013      3500
# 7/19/2014     3700
# 10/10/2012    3900
# 4/19/2015     5000
# dtype: int64

# %%
start_data_deposits.head(2)
# Out:
# 7/4/2014    2000
# 1/4/2015    2200
# dtype: int64
